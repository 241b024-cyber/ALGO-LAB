# %% [markdown]
# <a href="https://colab.research.google.com/github/241b024-cyber/ALGO-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
print("--- Custom Graph Input ---")
custom_graph = {}
num_nodes = int(input("Enter the number of nodes: "))

for _ in range(num_nodes):
    node = input("\nEnter node name (e.g., A): ").strip()
    custom_graph[node] = {}
    num_edges = int(input(f"How many neighbors does {node} have? "))
    for _ in range(num_edges):
        while True:
            edge_input_str = input(f"Enter neighbor and weight for {node} (e.g., B 5): ").strip()
            edge_data = edge_input_str.split()
            if len(edge_data) == 2:
                try:
                    neighbor = edge_data[0]
                    weight = int(edge_data[1])
                    break  # Exit inner while loop if input is valid
                except ValueError:
                    print("Invalid weight. Please enter an integer for the weight.")
            else:
                print("Invalid input format. Please enter neighbor and weight separated by a space (e.g., B 5).")
        custom_graph[node][neighbor] = weight

start_node = input("\nEnter the starting node: ").strip()
dist, prev = dijkstra_with_path(custom_graph, start_node)

print("\n--- Results ---")
for node in dist:
    path_str = get_path(prev, node)
    print(f"To {node}: Distance = {dist[node]}, Path = [{path_str}]")
# Out:
# --- Custom Graph Input ---

# %%
import collections

def dijkstra_with_path(graph, start):
    # Initialize distances and predecessors for path tracking
    distances = {node: float('inf') for node in graph}
    predecessors = {node: None for node in graph}
    distances[start] = 0
    visited = set()

    while len(visited) < len(graph):
        # Find the unvisited node with the smallest distance
        min_node = None
        for node in graph:
            if node not in visited:
                if min_node is None or distances[node] < distances[min_node]:
                    min_node = node

        if distances[min_node] == float('inf'):
            break

        visited.add(min_node)

# %%
expanded_graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10, 'E': 3},
    'C': {'A': 2, 'B': 5, 'D': 3, 'F': 8},
    'D': {'B': 10, 'C': 3, 'E': 7, 'F': 1},
    'E': {'B': 3, 'D': 7, 'F': 2},
    'F': {'C': 8, 'D': 1, 'E': 2}
}

# %%
test_sources = ['A', 'D', 'E']

for source in test_sources:
    print(f"\n--- Testing from Source Node: {source} ---")
    distances, predecessors = dijkstra_with_path(expanded_graph, source)
    for target in expanded_graph:
        path = get_path(predecessors, target)
        print(f"Path to {target}: {path} (Total Distance: {distances[target]})")
